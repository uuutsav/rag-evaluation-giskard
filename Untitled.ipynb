# %%
# 1. Setup and Configuration
# Force newer version 
# !pip install --upgrade pydantic litellm "giskard[llm]"
# Out:
# Requirement already satisfied: pydantic in ./.venv/lib/python3.10/site-packages (2.12.5)
# Requirement already satisfied: litellm in ./.venv/lib/python3.10/site-packages (1.81.15)
# Requirement already satisfied: giskard[llm] in ./.venv/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.10/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./.venv/lib/python3.10/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.10/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.2.0 in ./.venv/lib/python3.10/site-packages (from litellm) (1.2.1)
# Requirement already satisfied: tokenizers in ./.venv/lib/python3.10/site-packages (from litellm) (0.22.2)
# Requirement already satisfied: tiktoken>=0.7.0 in ./.venv/lib/python3.10/site-packages (from litellm) (0.12.0)
# Requirement already satisfied: aiohttp>=3.10 in ./.venv/lib/python3.10/site-packages (from litellm) (3.13.3)
# Requirement already satisfied: importlib-metadata>=6.8.0 in ./.venv/lib/python3.10/site-packages (from litellm) (8.7.1)
# Requirement already satisfied: openai>=2.8.0 in ./.venv/lib/python3.10/site-packages (from litellm) (2.24.0)
# Requirement already satisfied: click in ./.venv/lib/python3.10/site-packages (from litellm) (8.3.1)
# Requirement already satisfied: fastuuid>=0.13.0 in ./.venv/lib/python3.10/site-packages (from litellm) (0.14.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in ./.venv/lib/python3.10/site-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in ./.venv/lib/python3.10/site-packages (from litellm) (4.26.0)
# Requirement already satisfied: httpx>=0.23.0 in ./.venv/lib/python3.10/site-packages (from litellm) (0.28.1)
# Requirement already satisfied: scipy<1.12.0,>=1.7.3 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.7.2)
# Requirement already satisfied: numpy<2,>=1.26.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.1.1 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.1.2)
# Requirement already satisfied: xxhash>=3.2.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.6.0)
# Requirement already satisfied: chardet in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (6.0.0.post1)
# Requirement already satisfied: langdetect>=1.0.9 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.0.9)
# Requirement already satisfied: griffe<2.0.0,>=1.0.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.15.0)
# Requirement already satisfied: colorama in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.4.6)
# Requirement already satisfied: num2words>=0.5.13 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.5.14)
# Requirement already satisfied: pandas>=2.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (2.3.3)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (6.0.3)
# Requirement already satisfied: ipython in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (8.38.0)
# Requirement already satisfied: markdown in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.10.2)
# Requirement already satisfied: mixpanel>=4.4.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (4.11.1)
# Requirement already satisfied: zstandard>=0.10.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.25.0)
# Requirement already satisfied: mlflow-skinny>=2 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.5.1)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (24.2)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.0.0)
# Requirement already satisfied: requests>=2.19 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (2.32.5)
# Requirement already satisfied: bokeh<3.5,>=3.3.4 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.4.3)
# Requirement already satisfied: bert-score>=0.3.13 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.3.13)
# Requirement already satisfied: evaluate>=0.4.1 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.4.6)
# Requirement already satisfied: groq>=0.10.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.0.0)
# Requirement already satisfied: faiss-cpu<1.11.0,>=1.7.4 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.10.0)
# Requirement already satisfied: tenacity>=4.11.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (8.5.0)
# Requirement already satisfied: umap-learn>=0.5.5 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.5.11)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (0.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (6.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (1.22.0)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (25.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (1.8.0)
# Requirement already satisfied: torch>=1.0.0 in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (2.10.0)
# Requirement already satisfied: tqdm>=4.31.1 in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (4.67.3)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (3.10.8)
# Requirement already satisfied: transformers>=3.0.0 in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (5.2.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (2025.11.0)
# Requirement already satisfied: contourpy>=1.2 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (1.3.2)
# Requirement already satisfied: pillow>=7.1.0 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (12.1.1)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (6.5.4)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (2025.10.0)
# Requirement already satisfied: dill in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (4.5.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (1.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (0.70.18)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.10/site-packages (from groq>=0.10.0->giskard[llm]) (4.12.1)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from groq>=0.10.0->giskard[llm]) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.10/site-packages (from groq>=0.10.0->giskard[llm]) (1.9.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm) (2026.2.25)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm) (3.11)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.10/site-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.3)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.30.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (2025.9.1)
# Requirement already satisfied: six in ./.venv/lib/python3.10/site-packages (from langdetect>=1.0.9->giskard[llm]) (1.17.0)
# Requirement already satisfied: fastapi<1 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.125.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (1.39.1)
# Requirement already satisfied: cachetools<7,>=5.0.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (6.2.6)
# Requirement already satisfied: protobuf<7,>=3.12.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (4.25.8)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (3.1.46)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (1.39.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.92.0)
# Requirement already satisfied: uvicorn<1 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.41.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (1.27.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.5.5)
# Requirement already satisfied: docopt>=0.6.2 in ./.venv/lib/python3.10/site-packages (from num2words>=0.5.13->giskard[llm]) (0.6.2)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.10/site-packages (from openai>=2.8.0->litellm) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0->giskard[llm]) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0->giskard[llm]) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0->giskard[llm]) (2025.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests>=2.19->giskard[llm]) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests>=2.19->giskard[llm]) (3.4.4)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.0->giskard[llm]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.0->giskard[llm]) (3.6.0)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.10/site-packages (from tiktoken>=0.7.0->litellm) (2026.2.19)
# Requirement already satisfied: pynndescent>=0.5 in ./.venv/lib/python3.10/site-packages (from umap-learn>=0.5.5->giskard[llm]) (0.6.0)
# Requirement already satisfied: numba>=0.51.2 in ./.venv/lib/python3.10/site-packages (from umap-learn>=0.5.5->giskard[llm]) (0.64.0)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (2.19.2)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (0.6.3)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (1.3.1)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (5.2.1)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (5.14.3)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (0.2.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (3.0.52)
# Requirement already satisfied: google-auth~=2.0 in ./.venv/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (2.48.0)
# Requirement already satisfied: pyarrow>=21.0.0 in ./.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate>=0.4.1->giskard[llm]) (23.0.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate>=0.4.1->giskard[llm]) (3.24.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny>=2->giskard[llm]) (0.0.4)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in ./.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny>=2->giskard[llm]) (0.50.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny>=2->giskard[llm]) (4.0.12)
# Requirement already satisfied: shellingham in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (1.5.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (1.3.1)
# Requirement already satisfied: typer-slim in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (0.24.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->giskard[llm]) (0.8.6)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in ./.venv/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn>=0.5.5->giskard[llm]) (0.46.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in ./.venv/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny>=2->giskard[llm]) (0.60b1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->giskard[llm]) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->giskard[llm]) (0.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (11.3.3.83)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.90)
# Requirement already satisfied: cuda-bindings==12.9.4 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.9.4)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (3.4.2)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (3.6.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.5.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (10.3.9.90)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.93)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (9.10.2.21)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (3.4.5)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.93)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (11.7.3.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in ./.venv/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.3.5)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score>=0.3.13->giskard[llm]) (0.7.0)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (3.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (4.61.1)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython->giskard[llm]) (2.2.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack_data->ipython->giskard[llm]) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython->giskard[llm]) (3.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny>=2->giskard[llm]) (5.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (4.9.1)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (46.0.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.3.0)
# Requirement already satisfied: typer>=0.24.0 in ./.venv/lib/python3.10/site-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (0.24.1)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (0.6.2)
# Requirement already satisfied: rich>=12.3.0 in ./.venv/lib/python3.10/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (14.3.3)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (0.1.2)

# %%
# !pip install --upgrade docarray pydantic litellm langchain langchain-community "giskard[llm]"
# Out:
# Requirement already satisfied: docarray in ./.venv/lib/python3.10/site-packages (0.41.0)
# Requirement already satisfied: pydantic in ./.venv/lib/python3.10/site-packages (2.12.5)
# Requirement already satisfied: litellm in ./.venv/lib/python3.10/site-packages (1.81.15)
# Requirement already satisfied: langchain in ./.venv/lib/python3.10/site-packages (1.2.10)
# Requirement already satisfied: langchain-community in ./.venv/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: giskard[llm] in ./.venv/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: types-requests>=2.28.11.6 in ./.venv/lib/python3.10/site-packages (from docarray) (2.32.4.20260107)
# Requirement already satisfied: orjson>=3.8.2 in ./.venv/lib/python3.10/site-packages (from docarray) (3.11.7)
# Requirement already satisfied: rich>=13.1.0 in ./.venv/lib/python3.10/site-packages (from docarray) (14.3.3)
# Requirement already satisfied: numpy>=1.17.3 in ./.venv/lib/python3.10/site-packages (from docarray) (1.26.4)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./.venv/lib/python3.10/site-packages (from docarray) (0.9.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.10/site-packages (from pydantic) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.10/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./.venv/lib/python3.10/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: tokenizers in ./.venv/lib/python3.10/site-packages (from litellm) (0.22.2)
# Requirement already satisfied: importlib-metadata>=6.8.0 in ./.venv/lib/python3.10/site-packages (from litellm) (8.7.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in ./.venv/lib/python3.10/site-packages (from litellm) (4.26.0)
# Requirement already satisfied: click in ./.venv/lib/python3.10/site-packages (from litellm) (8.3.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in ./.venv/lib/python3.10/site-packages (from litellm) (3.1.6)
# Requirement already satisfied: python-dotenv>=0.2.0 in ./.venv/lib/python3.10/site-packages (from litellm) (1.2.1)
# Requirement already satisfied: openai>=2.8.0 in ./.venv/lib/python3.10/site-packages (from litellm) (2.24.0)
# Requirement already satisfied: aiohttp>=3.10 in ./.venv/lib/python3.10/site-packages (from litellm) (3.13.3)
# Requirement already satisfied: tiktoken>=0.7.0 in ./.venv/lib/python3.10/site-packages (from litellm) (0.12.0)
# Requirement already satisfied: httpx>=0.23.0 in ./.venv/lib/python3.10/site-packages (from litellm) (0.28.1)
# Requirement already satisfied: fastuuid>=0.13.0 in ./.venv/lib/python3.10/site-packages (from litellm) (0.14.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in ./.venv/lib/python3.10/site-packages (from langchain) (1.0.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in ./.venv/lib/python3.10/site-packages (from langchain) (1.2.15)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./.venv/lib/python3.10/site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./.venv/lib/python3.10/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./.venv/lib/python3.10/site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./.venv/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./.venv/lib/python3.10/site-packages (from langchain-community) (2.0.47)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./.venv/lib/python3.10/site-packages (from langchain-community) (0.7.6)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./.venv/lib/python3.10/site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./.venv/lib/python3.10/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: colorama in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.4.6)
# Requirement already satisfied: mlflow-skinny>=2 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.5.1)
# Requirement already satisfied: zstandard>=0.10.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.25.0)
# Requirement already satisfied: xxhash>=3.2.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.6.0)
# Requirement already satisfied: pandas>=2.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.7.2)
# Requirement already satisfied: scipy<1.12.0,>=1.7.3 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.11.4)
# Requirement already satisfied: cloudpickle>=1.1.1 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.1.2)
# Requirement already satisfied: langdetect>=1.0.9 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.0.9)
# Requirement already satisfied: num2words>=0.5.13 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.5.14)
# Requirement already satisfied: chardet in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (6.0.0.post1)
# Requirement already satisfied: griffe<2.0.0,>=1.0.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.15.0)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.0.0)
# Requirement already satisfied: ipython in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (8.38.0)
# Requirement already satisfied: mixpanel>=4.4.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (4.11.1)
# Requirement already satisfied: markdown in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.10.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (24.2)
# Requirement already satisfied: groq>=0.10.0 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.0.0)
# Requirement already satisfied: faiss-cpu<1.11.0,>=1.7.4 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (1.10.0)
# Requirement already satisfied: bokeh<3.5,>=3.3.4 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (3.4.3)
# Requirement already satisfied: bert-score>=0.3.13 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.3.13)
# Requirement already satisfied: evaluate>=0.4.1 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.4.6)
# Requirement already satisfied: umap-learn>=0.5.5 in ./.venv/lib/python3.10/site-packages (from giskard[llm]) (0.5.11)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (6.7.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (25.4.0)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (1.22.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10->litellm) (0.4.1)
# Requirement already satisfied: tqdm>=4.31.1 in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (4.67.3)
# Requirement already satisfied: transformers>=3.0.0 in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (5.2.0)
# Requirement already satisfied: torch>=1.0.0 in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (2.10.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.10/site-packages (from bert-score>=0.3.13->giskard[llm]) (3.10.8)
# Requirement already satisfied: contourpy>=1.2 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (1.3.2)
# Requirement already satisfied: pillow>=7.1.0 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (12.1.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (2025.11.0)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.10/site-packages (from bokeh<3.5,>=3.3.4->giskard[llm]) (6.5.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.10/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: datasets>=2.0.0 in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (4.5.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (1.4.1)
# Requirement already satisfied: multiprocess in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (0.70.18)
# Requirement already satisfied: dill in ./.venv/lib/python3.10/site-packages (from evaluate>=0.4.1->giskard[llm]) (0.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.10/site-packages (from groq>=0.10.0->giskard[llm]) (1.9.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from groq>=0.10.0->giskard[llm]) (1.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.10/site-packages (from groq>=0.10.0->giskard[llm]) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm) (2026.2.25)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm) (3.11)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.10/site-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.3)
# Requirement already satisfied: rpds-py>=0.25.0 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.30.0)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm) (2025.9.1)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: six in ./.venv/lib/python3.10/site-packages (from langdetect>=1.0.9->giskard[llm]) (1.17.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in ./.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in ./.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in ./.venv/lib/python3.10/site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (6.2.6)
# Requirement already satisfied: uvicorn<1 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.41.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (1.39.1)
# Requirement already satisfied: fastapi<1 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.125.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (3.1.46)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (1.27.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.92.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (0.5.5)
# Requirement already satisfied: protobuf<7,>=3.12.0 in ./.venv/lib/python3.10/site-packages (from mlflow-skinny>=2->giskard[llm]) (4.25.8)
# Requirement already satisfied: docopt>=0.6.2 in ./.venv/lib/python3.10/site-packages (from num2words>=0.5.13->giskard[llm]) (0.6.2)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.10/site-packages (from openai>=2.8.0->litellm) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0->giskard[llm]) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0->giskard[llm]) (2025.3)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas>=2.0->giskard[llm]) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich>=13.1.0->docarray) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.10/site-packages (from rich>=13.1.0->docarray) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.0->giskard[llm]) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.10/site-packages (from scikit-learn>=1.0->giskard[llm]) (1.5.3)
# Requirement already satisfied: greenlet>=1 in ./.venv/lib/python3.10/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.10/site-packages (from tiktoken>=0.7.0->litellm) (2026.2.19)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->docarray) (1.1.0)
# Requirement already satisfied: numba>=0.51.2 in ./.venv/lib/python3.10/site-packages (from umap-learn>=0.5.5->giskard[llm]) (0.64.0)
# Requirement already satisfied: pynndescent>=0.5 in ./.venv/lib/python3.10/site-packages (from umap-learn>=0.5.5->giskard[llm]) (0.6.0)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (1.3.1)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (3.0.52)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (0.2.1)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (5.2.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.10/site-packages (from ipython->giskard[llm]) (0.6.3)
# Requirement already satisfied: google-auth~=2.0 in ./.venv/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (2.48.0)
# Requirement already satisfied: pyarrow>=21.0.0 in ./.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate>=0.4.1->giskard[llm]) (23.0.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate>=0.4.1->giskard[llm]) (3.24.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny>=2->giskard[llm]) (0.0.4)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in ./.venv/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny>=2->giskard[llm]) (0.50.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny>=2->giskard[llm]) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (1.3.1)
# Requirement already satisfied: shellingham in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (1.5.4)
# Requirement already satisfied: typer-slim in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (0.24.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython->giskard[llm]) (0.8.6)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in ./.venv/lib/python3.10/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->docarray) (0.1.2)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in ./.venv/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn>=0.5.5->giskard[llm]) (0.46.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in ./.venv/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny>=2->giskard[llm]) (0.60b1)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython->giskard[llm]) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->giskard[llm]) (0.6.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (11.3.3.83)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (11.7.3.90)
# Requirement already satisfied: networkx>=2.5.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (3.4.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (2.27.5)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (9.10.2.21)
# Requirement already satisfied: cuda-bindings==12.9.4 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.9.4)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (0.7.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.90)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.90)
# Requirement already satisfied: triton==3.6.0 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (3.6.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (10.3.9.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.93)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.5.8.93)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.14.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.93)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (3.4.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.venv/lib/python3.10/site-packages (from torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in ./.venv/lib/python3.10/site-packages (from cuda-bindings==12.9.4->torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.3.5)
# Requirement already satisfied: safetensors>=0.4.3 in ./.venv/lib/python3.10/site-packages (from transformers>=3.0.0->bert-score>=0.3.13->giskard[llm]) (0.7.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (3.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (4.61.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib->bert-score>=0.3.13->giskard[llm]) (1.4.9)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython->giskard[llm]) (2.2.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack_data->ipython->giskard[llm]) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython->giskard[llm]) (3.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny>=2->giskard[llm]) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (4.9.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score>=0.3.13->giskard[llm]) (1.3.0)
# Requirement already satisfied: typer>=0.24.0 in ./.venv/lib/python3.10/site-packages (from typer-slim->huggingface-hub>=0.7.0->evaluate>=0.4.1->giskard[llm]) (0.24.1)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (0.6.2)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny>=2->giskard[llm]) (3.0)

# %%
import pydantic
print(pydantic.__version__)
# Out:
# 2.12.5

# %%
import os
from dotenv import load_dotenv
import giskard

load_dotenv()
os.environ["USER_AGENT"] = "my-rag-evaluation-app"

# Use the standard gemini 1.5 flash model
giskard.llm.set_llm_model("gemini/gemini-2.5-flash")

# Tell Giskard to use the universally available Google embedding model
# giskard.llm.set_embedding_model("gemini/embedding-001")
# giskard.llm.set_embedding_model("gemini/text-embedding-004")
giskard.llm.set_embedding_model("gemini/gemini-embedding-001")

# %%
# 2. Scrape the Website

# %%
from langchain_community.document_loaders import WebBaseLoader

# UPDATE: The new, correct import path for modern LangChain
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)

loader = WebBaseLoader("https://www.ml.school/") #1
documents = loader.load_and_split(text_splitter)

print(f"Scraped {len(documents)} documents.")
# Out:
# Scraped 10 documents.

# %%
# 3: Embed using Gemini and Store in Vector DB

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import DocArrayInMemorySearch

# Must include the "models/" prefix!
# embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
# embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

vectorstore = DocArrayInMemorySearch.from_documents(
    documents, embedding=embeddings
)

print("Successfully embedded and stored in VectorDB!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from langchain_google_genai import GoogleGenerativeAIEmbeddings
#       2 from langchain_community.vectorstores import DocArrayInMemorySearch
#       4 # Must include the "models/" prefix!
#       5 # embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
#       6 # embeddings = GoogleGenerativeAIEmbeddings(model="models/text-embedding-004")
#
# File ~/Desktop/Rise23+2/AI/Hehe/Giskard/rag-evaluation-gemini/.venv/lib/python3.10/site-packages/langchain_google_genai/__init__.py:59
#       1 """**LangChain Google Generative AI Integration**
#       2
#       3 This module integrates Google's Generative AI models, specifically the Gemini series, with the LangChain framework. It provides classes for interacting with chat models and generating embeddings, leveraging Google's advanced AI capabilities.
#    (...)
#      55 ```
#      56 """  # noqa: E501
#      58 from langchain_google_genai._enums import HarmBlockThreshold, HarmCategory
# ---> 59 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      60 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      61 from langchain_google_genai.genai_aqa import (
#      62     AqaInput,
#      63     AqaOutput,
#      64     GenAIAqa,
#      65 )
#
# File ~/Desktop/Rise23+2/AI/Hehe/Giskard/rag-evaluation-gemini/.venv/lib/python3.10/site-packages/langchain_google_genai/chat_models.py:78
#      72 from langchain_core.output_parsers.openai_tools import (
#      73     JsonOutputToolsParser,
#      74     PydanticToolsParser,
#      75     parse_tool_calls,
#      76 )
#      77 from langchain_core.outputs import ChatGeneration, ChatGenerationChunk, ChatResult
# ---> 78 from langchain_core.pydantic_v1 import BaseModel, Field, SecretStr, root_validator
#      79 from langchain_core.runnables import Runnable, RunnablePassthrough
#      80 from langchain_core.utils import get_from_dict_or_env
#
# ModuleNotFoundError: No module named 'langchain_core.pydantic_v1'

# %%
# Compatibility update
# !pip install --upgrade langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in ./.venv/lib/python3.10/site-packages (1.0.10)
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-4.2.1-py3-none-any.whl (66 kB)
# Collecting google-genai<2.0.0,>=1.56.0
#   Using cached google_genai-1.64.0-py3-none-any.whl (728 kB)
# Collecting filetype<2.0.0,>=1.2.0
#   Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in ./.venv/lib/python3.10/site-packages (from langchain-google-genai) (2.12.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in ./.venv/lib/python3.10/site-packages (from langchain-google-genai) (1.2.15)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.12.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (8.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.32.5)
# Requirement already satisfied: google-auth[requests]<3.0.0,>=2.47.0 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.48.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: aiohttp>=3.10.11 in ./.venv/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.13.3)
# Collecting websockets<15.1.0,>=13.0.0
#   Using cached websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.7.6)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.14.1)
# Requirement already satisfied: packaging>=23.2.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (24.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./.venv/lib/python3.10/site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (1.33)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.5)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (6.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.8.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.0.3)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (25.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.22.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.10/site-packages (from aiohttp>=3.10.11->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.10/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (0.25.0)
# Requirement already satisfied: xxhash>=3.0.0 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.6.0)
# Requirement already satisfied: orjson>=3.9.14 in ./.venv/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain-google-genai) (3.11.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.4.4)
# Requirement already satisfied: cffi>=2.0.0 in ./.venv/lib/python3.10/site-packages (from cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (0.6.2)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai) (3.0)
# Installing collected packages: filetype, websockets, google-genai, langchain-google-genai
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 1.0.10
#     Uninstalling langchain-google-genai-1.0.10:
#       Successfully uninstalled langchain-google-genai-1.0.10
# Successfully installed filetype-1.2.0 google-genai-1.64.0 langchain-google-genai-4.2.1 websockets-15.0.1

# %%
# Cell 4: Create the Knowledge Base & Generate Tests

# %%
import pandas as pd
from giskard.rag import KnowledgeBase, generate_testset

df = pd.DataFrame([d.page_content for d in documents], columns=["text"])
knowledge_base = KnowledgeBase(df)

# Generate the test set (using 15 questions for speed; scale up later)
testset = generate_testset(
    knowledge_base,
    num_questions=15,
    agent_description="A chatbot answering questions about the Machine Learning School Website",
)

testset.save("test-set.jsonl")

# Let's peek at a generated question
test_set_df = testset.to_pandas()
print("Sample Question:", test_set_df.iloc[0]['question'])
print("Expected Answer:", test_set_df.iloc[0]['reference_answer'])
# Out:
# 2026-02-25 12:21:57,444 pid:160850 MainThread giskard.rag  INFO     Finding topics in the knowledge base.
# /home/utsav/Desktop/Rise23+2/AI/Hehe/Giskard/rag-evaluation-gemini/.venv/lib/python3.10/site-packages/umap/umap_.py:2462: UserWarning: n_neighbors is larger than the dataset size; truncating to X.shape[0] - 1
#   warn(
# 2026-02-25 12:22:08,303 pid:160850 MainThread giskard.rag  INFO     Found 1 topics in the knowledge base.
# Generating questions:   0%|          | 0/15 [00:00<?, ?it/s]
# Sample Question: How much time should be allocated weekly to complete the program?
# Expected Answer: You should set aside a minimum of 4 hours every week during the three weeks of the program to attend the live sessions or watch the recordings. An additional 2 - 4 hours will be needed if you plan to go through the codebase.

# %%
# Cell 5: Build the Gemini RAG Chain

# %%
# !pip install --force-reinstall langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-4.2.1-py3-none-any.whl (66 kB)
# Collecting langchain-core<2.0.0,>=1.2.5
#   Using cached langchain_core-1.2.15-py3-none-any.whl (502 kB)
# Collecting google-genai<2.0.0,>=1.56.0
#   Using cached google_genai-1.64.0-py3-none-any.whl (728 kB)
# Collecting filetype<2.0.0,>=1.2.0
#   Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting pydantic<3.0.0,>=2.0.0
#   Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Collecting websockets<15.1.0,>=13.0.0
#   Using cached websockets-15.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (181 kB)
# Collecting anyio<5.0.0,>=4.8.0
#   Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting typing-extensions<5.0.0,>=4.11.0
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting requests<3.0.0,>=2.28.1
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting google-auth[requests]<3.0.0,>=2.47.0
#   Using cached google_auth-2.48.0-py3-none-any.whl (236 kB)
# Collecting aiohttp>=3.10.11
#   Using cached aiohttp-3.13.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
# Collecting tenacity<9.2.0,>=8.2.3
#   Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Collecting httpx<1.0.0,>=0.28.1
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<1.0.0,>=0.3.45
#   Using cached langsmith-0.7.6-py3-none-any.whl (325 kB)
# Collecting packaging>=23.2.0
#   Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Collecting pyyaml<7.0.0,>=5.3.0
#   Using cached pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
# Collecting uuid-utils<1.0,>=0.12.0
#   Using cached uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Collecting pydantic-core==2.41.5
#   Using cached pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting aiosignal>=1.4.0
#   Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (243 kB)
# Collecting propcache>=0.2.0
#   Using cached propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Collecting async-timeout<6.0,>=4.0
#   Using cached async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting yarl<2.0,>=1.17.0
#   Using cached yarl-1.22.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (346 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Collecting exceptiongroup>=1.0.2
#   Using cached exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting idna>=2.8
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting cryptography>=38.0.3
#   Using cached cryptography-46.0.5-cp38-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Collecting certifi
#   Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting zstandard>=0.23.0
#   Using cached zstandard-0.25.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
# Collecting requests-toolbelt>=1.0.0
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting xxhash>=3.0.0
#   Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Collecting orjson>=3.9.14
#   Using cached orjson-3.11.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting cffi>=2.0.0
#   Using cached cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
# Collecting pyasn1<0.7.0,>=0.6.1
#   Using cached pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Collecting pycparser
#   Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: filetype, zstandard, xxhash, websockets, uuid-utils, urllib3, typing-extensions, tenacity, sniffio, pyyaml, pycparser, pyasn1, propcache, packaging, orjson, jsonpointer, idna, h11, frozenlist, distro, charset_normalizer, certifi, attrs, async-timeout, annotated-types, aiohappyeyeballs, typing-inspection, rsa, requests, pydantic-core, pyasn1-modules, multidict, jsonpatch, httpcore, exceptiongroup, cffi, aiosignal, yarl, requests-toolbelt, pydantic, cryptography, anyio, httpx, google-auth, aiohttp, langsmith, langchain-core, google-genai, langchain-google-genai
#   Attempting uninstall: filetype
#     Found existing installation: filetype 1.2.0
#     Uninstalling filetype-1.2.0:
#       Successfully uninstalled filetype-1.2.0
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.25.0
#     Uninstalling zstandard-0.25.0:
#       Successfully uninstalled zstandard-0.25.0
#   Attempting uninstall: xxhash
#     Found existing installation: xxhash 3.6.0
#     Uninstalling xxhash-3.6.0:
#       Successfully uninstalled xxhash-3.6.0
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: uuid-utils
#     Found existing installation: uuid_utils 0.14.1
#     Uninstalling uuid_utils-0.14.1:
#       Successfully uninstalled uuid_utils-0.14.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.6.3
#     Uninstalling urllib3-2.6.3:
#       Successfully uninstalled urllib3-2.6.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.1
#     Uninstalling sniffio-1.3.1:
#       Successfully uninstalled sniffio-1.3.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: pycparser
#     Found existing installation: pycparser 3.0
#     Uninstalling pycparser-3.0:
#       Successfully uninstalled pycparser-3.0
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.6.2
#     Uninstalling pyasn1-0.6.2:
#       Successfully uninstalled pyasn1-0.6.2
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.4.1
#     Uninstalling propcache-0.4.1:
#       Successfully uninstalled propcache-0.4.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.11.7
#     Uninstalling orjson-3.11.7:
#       Successfully uninstalled orjson-3.11.7
#   Attempting uninstall: jsonpointer
#     Found existing installation: jsonpointer 3.0.0
#     Uninstalling jsonpointer-3.0.0:
#       Successfully uninstalled jsonpointer-3.0.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: h11
#     Found existing installation: h11 0.16.0
#     Uninstalling h11-0.16.0:
#       Successfully uninstalled h11-0.16.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.8.0
#     Uninstalling frozenlist-1.8.0:
#       Successfully uninstalled frozenlist-1.8.0
#   Attempting uninstall: distro
#     Found existing installation: distro 1.9.0
#     Uninstalling distro-1.9.0:
#       Successfully uninstalled distro-1.9.0
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.4
#     Uninstalling charset-normalizer-3.4.4:
#       Successfully uninstalled charset-normalizer-3.4.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2026.2.25
#     Uninstalling certifi-2026.2.25:
#       Successfully uninstalled certifi-2026.2.25
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.4.0
#     Uninstalling attrs-25.4.0:
#       Successfully uninstalled attrs-25.4.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.3
#     Uninstalling async-timeout-4.0.3:
#       Successfully uninstalled async-timeout-4.0.3
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.6.1
#     Uninstalling aiohappyeyeballs-2.6.1:
#       Successfully uninstalled aiohappyeyeballs-2.6.1
#   Attempting uninstall: typing-inspection
#     Found existing installation: typing-inspection 0.4.2
#     Uninstalling typing-inspection-0.4.2:
#       Successfully uninstalled typing-inspection-0.4.2
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9.1
#     Uninstalling rsa-4.9.1:
#       Successfully uninstalled rsa-4.9.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.5
#     Uninstalling requests-2.32.5:
#       Successfully uninstalled requests-2.32.5
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.5
#     Uninstalling pydantic_core-2.41.5:
#       Successfully uninstalled pydantic_core-2.41.5
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1_modules 0.4.2
#     Uninstalling pyasn1_modules-0.4.2:
#       Successfully uninstalled pyasn1_modules-0.4.2
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.7.1
#     Uninstalling multidict-6.7.1:
#       Successfully uninstalled multidict-6.7.1
#   Attempting uninstall: jsonpatch
#     Found existing installation: jsonpatch 1.33
#     Uninstalling jsonpatch-1.33:
#       Successfully uninstalled jsonpatch-1.33
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.9
#     Uninstalling httpcore-1.0.9:
#       Successfully uninstalled httpcore-1.0.9
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.3.1
#     Uninstalling exceptiongroup-1.3.1:
#       Successfully uninstalled exceptiongroup-1.3.1
#   Attempting uninstall: cffi
#     Found existing installation: cffi 2.0.0
#     Uninstalling cffi-2.0.0:
#       Successfully uninstalled cffi-2.0.0
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.4.0
#     Uninstalling aiosignal-1.4.0:
#       Successfully uninstalled aiosignal-1.4.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.22.0
#     Uninstalling yarl-1.22.0:
#       Successfully uninstalled yarl-1.22.0
#   Attempting uninstall: requests-toolbelt
#     Found existing installation: requests-toolbelt 1.0.0
#     Uninstalling requests-toolbelt-1.0.0:
#       Successfully uninstalled requests-toolbelt-1.0.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.5
#     Uninstalling pydantic-2.12.5:
#       Successfully uninstalled pydantic-2.12.5
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 46.0.5
#     Uninstalling cryptography-46.0.5:
#       Successfully uninstalled cryptography-46.0.5
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.12.1
#     Uninstalling anyio-4.12.1:
#       Successfully uninstalled anyio-4.12.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.48.0
#     Uninstalling google-auth-2.48.0:
#       Successfully uninstalled google-auth-2.48.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.3
#     Uninstalling aiohttp-3.13.3:
#       Successfully uninstalled aiohttp-3.13.3
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.7.6
#     Uninstalling langsmith-0.7.6:
#       Successfully uninstalled langsmith-0.7.6
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.15
#     Uninstalling langchain-core-1.2.15:
#       Successfully uninstalled langchain-core-1.2.15
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.64.0
#     Uninstalling google-genai-1.64.0:
#       Successfully uninstalled google-genai-1.64.0
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 4.2.1
#     Uninstalling langchain-google-genai-4.2.1:
#       Successfully uninstalled langchain-google-genai-4.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow-skinny 3.5.1 requires packaging<26, but you have packaging 26.0 which is incompatible.
# langchain-classic 1.0.1 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-types-0.7.0 anyio-4.12.1 async-timeout-5.0.1 attrs-25.4.0 certifi-2026.2.25 cffi-2.0.0 charset_normalizer-3.4.4 cryptography-46.0.5 distro-1.9.0 exceptiongroup-1.3.1 filetype-1.2.0 frozenlist-1.8.0 google-auth-2.48.0 google-genai-1.64.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-1.2.15 langchain-google-genai-4.2.1 langsmith-0.7.6 multidict-6.7.1 orjson-3.11.7 packaging-26.0 propcache-0.4.1 pyasn1-0.6.2 pyasn1-modules-0.4.2 pycparser-3.0 pydantic-2.12.5 pydantic-core-2.41.5 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 rsa-4.9.1 sniffio-1.3.1 tenacity-9.1.4 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.6.3 uuid-utils-0.14.1 websockets-15.0.1 xxhash-3.6.0 yarl-1.22.0 zstandard-0.25.0

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from operator import itemgetter

retriever = vectorstore.as_retriever()

template = """
Answer the question based on the context below. If you can't 
answer the question, reply "I don't know".

Context: {context}

Question: {question}
"""
prompt = PromptTemplate.from_template(template)

# Use Gemini 1.5 Flash
model = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0)

chain = (
    {
        "context": itemgetter("question") | retriever,
        "question": itemgetter("question"),
    }
    | prompt
    | model
    | StrOutputParser()
)

# Test the chain manually
print("Testing chain:")
print(chain.invoke({"question": "What is the Machine Learning School?"}))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 from langchain_google_genai import ChatGoogleGenerativeAI
#       2 from langchain.prompts import PromptTemplate
#       3 from langchain_core.output_parsers import StrOutputParser
#
# File ~/Desktop/Rise23+2/AI/Hehe/Giskard/rag-evaluation-gemini/.venv/lib/python3.10/site-packages/langchain_google_genai/__init__.py:39
#       1 """LangChain Google Gen AI integration.
#       2
#       3 !!! note "Vertex AI consolidation & compatibility"
#    (...)
#      36 more information on usage of this package.
#      37 """
# ---> 39 from langchain_google_genai._enums import (
#      40     ComputerUse,
#      41     Environment,
#      42     HarmBlockThreshold,
#      43     HarmCategory,
#      44     MediaResolution,
#      45     Modality,
#      46 )
#      47 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      48 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#
# ImportError: cannot import name 'ComputerUse' from 'langchain_google_genai._enums' (/home/utsav/Desktop/Rise23+2/AI/Hehe/Giskard/rag-evaluation-gemini/.venv/lib/python3.10/site-packages/langchain_google_genai/_enums.py)
